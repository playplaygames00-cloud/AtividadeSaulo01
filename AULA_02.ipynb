# %% [markdown]
# # OBJETIVO DA ATIVIDADE
#
# Crie um código que pergunte um número inteiro ao usuário e informe na tela se esse número é Positivo, Negativo ou Zero.

# %%
print ("== SEU NÚMERO É O QUE?? ==")
print ("Para iniciarmos digite o seu número:")
numero = int (input())

if numero >= 1:
  result = "Seu número é positivo"
elif numero <= -1:
  result = "Seu número é negativo"
else:
  result = "Seu número é o zero"

clear_output (True)

print(f"Seu número é {numero}")
print(result)
